# %%
import seaborn as sns
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
sns.set_style('whitegrid')

# %%
ping = sns.load_dataset('penguins')
ping
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
ping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
ping.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
sns.displot(ping['bill_length_mm']).set(title='Displot')

# %%
sns.histplot(ping['bill_length_mm']).set(title='histplot')
# Out:
# [Text(0.5, 1.0, 'histplot')]

# %%
sns.jointplot(data = ping, x='bill_length_mm',y='bill_depth_mm',hue='species')

# %% [markdown]
# # Mudando o estilo

# %%
sns.jointplot(data = ping, x='bill_length_mm',y='bill_depth_mm',hue='species',kind='kde')

# %%
sns.jointplot(data = ping, x='bill_length_mm',y='bill_depth_mm',kind = 'reg', marker='+')

# %%
sns.jointplot(data = ping, x='bill_length_mm',y='bill_depth_mm',kind='hist',hue='species',bins=40)

# %%
sns.jointplot(data = ping, x='bill_length_mm',y='bill_depth_mm',kind='hex')

# %%
sns.lmplot(data=ping,x='body_mass_g',y='bill_depth_mm',hue='sex')

# %%
ping.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.pairplot(ping,hue='species')

# %%
sns.barplot(data=ping,x='species',y='bill_length_mm').set(title='Tamanho da pico por especies')
plt.xlabel('Especies',fontsize=10)
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
sns.countplot(data = ping,x='species')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
ping['species'].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
sns.boxplot(data=ping,x='island',y='body_mass_g',hue='sex')
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
sns.violinplot(data = ping, x = 'species', y = 'flipper_length_mm',hue='sex',split=True)
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %%
sns.heatmap(ping.corr(),annot=True, linewidth = 2,linecolor='black')
# Out:
# /tmp/ipykernel_1659/175377807.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ping.corr(),annot=True, linewidth = 2,linecolor='black')
# <Axes: >

# %%
ping.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
p = sns.FacetGrid(ping, col='island',row='species')
p.map(sns.histplot,'bill_depth_mm',bins=30,kde=True)

# %%
sns.relplot(data = ping,x = 'bill_depth_mm', y = 'bill_length_mm', hue='sex',size='body_mass_g',sizes=(1,100))

# %%
sns.scatterplot(data = ping,x = 'bill_depth_mm', y = 'bill_length_mm', hue='sex')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>
