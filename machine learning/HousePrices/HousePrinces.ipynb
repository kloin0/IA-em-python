# %% [markdown]
# Peça a um comprador de casa para descrever a casa dos seus sonhos e provavelmente não começará com a altura do teto do porão ou a proximidade de uma ferrovia leste-oeste.
#
# Mas o conjunto de dados desta competição de playground prova que muito mais influencia as negociações de preços do que o número de quartos ou uma cerca branca.
#
# Com 79 variáveis explicativas que descrevem (quase) todos os aspectos das casas residenciais em Ames, Iowa, esta competição desafia você a prever o preço final de cada casa.
#
# Praticar Habilidades
# Engenharia de recursos criativos
# Técnicas de regressão avançadas, como floresta aleatória e aumento de gradiente

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.impute import SimpleImputer 
from xgboost import XGBRegressor 
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
dados = pd.read_csv('train.csv')
display(dados.head())
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#limpando os dados para x e y 
y = dados['SalePrice']
x = dados.drop('SalePrice',axis=1).select_dtypes(exclude=['object'])

# %%
x_treino,x_teste,y_treino,y_teste = train_test_split(x.values,y.values,test_size=2/3,random_state=0)
# lidando com valores ausentes 
dados_limpo = SimpleImputer()
x_treino = dados_limpo.fit_transform(x_treino)
x_teste = dados_limpo.fit_transform(x_teste)
cerebro = XGBRegressor()
cerebro.fit(x_treino,y_treino,verbose=False)
predictons = cerebro.predict(x_teste)
print('Erro é de {:.2f}'.format(mean_absolute_error(predictons,y_teste)))
# Out:
# Erro é de 20448.40

# %%
# usando RandomFlorestClassifier 
floresta = RandomForestClassifier(n_estimators=5000,
                                            max_depth = None,
                                            max_features = 'auto', 
                                            max_samples = None, 
                                            random_state=1)
floresta.fit(x_treino,y_treino)
accuracy_score(y_teste,floresta.predict(x_teste))
# Out:
# /home/gustavohenrique06112005/.local/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
